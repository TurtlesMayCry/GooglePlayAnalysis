# %%
# Google Playstore Analysis
# Eric Gong, Raian Rahman, Tony Li, Russel Tsang
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('googleplaystore.csv', low_memory=False) 
data2 = pd.read_csv('googleplaystoresentiments.csv', low_memory=False)
app = data['App'].value_counts()
app.describe()
# Out:
# count    8881.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: App, dtype: float64

# %%
plt.figure(figsize=(20,9))
plt.xticks(rotation=90, fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Count', fontsize=20)
plt.xlabel('Category', fontsize=20)
plt.title('Count of Categories', fontsize=20)
sns.countplot(x=data['Category'])

# %%
plt.xticks(rotation=90, fontsize=12)
plot = sns.countplot(x=data['Content Rating'])

# %%
sns.boxplot(y='Content Rating', x='Rating', data=data)

# %%
# use
plt.figure(figsize=(15,10))
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
sns.countplot(x=data['Rating'])

# %%
plt.figure(figsize=(15,15))
sns.boxplot(y='Category', x='Rating', data=data)

# %%
sns.countplot(x=data['Type'])

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y='Type', x='Rating', data=data)

# %%
corr = data.corr()
sns.heatmap(corr)

# %%
corr
# Out:
#            Rating   Reviews     Price
# Rating   1.000000  0.058174 -0.017927
# Reviews  0.058174  1.000000 -0.007040
# Price   -0.017927 -0.007040  1.000000

# %%
dept = data2['Sentiment'].value_counts()
sns.countplot(y=data2['Sentiment'], order=dept.index)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(y='Category', x='Sentiment_Polarity', data=data2)

# %%
plt.figure(figsize=(10,10))
sns.regplot(y='Rating', x='Sentiment_Polarity', data=data2, line_kws={"linewidth": 5, "color": "red"})

# %%
data2.corr()
# Out:
#                           Rating   Reviews     Price  Sentiment_Polarity  \
# Rating                  1.000000  0.075620 -0.010110            0.093863
# Reviews                 0.075620  1.000000 -0.020603           -0.079978
# Price                  -0.010110 -0.020603  1.000000            0.024198
# Sentiment_Polarity      0.093863 -0.079978  0.024198            1.000000
# Sentiment_Subjectivity  0.069120 -0.009254  0.003214            0.259651
#
#                         Sentiment_Subjectivity
# Rating                                0.069120
# Reviews                              -0.009254
# Price                                 0.003214
# Sentiment_Polarity                    0.259651
# Sentiment_Subjectivity                1.000000

# %%
plt.figure(figsize=(10,10))
sns.boxplot(y='Installs', x='Rating', data=data)
